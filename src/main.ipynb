# %%
from api.api import API_Client

client = API_Client()

# %%
# get records
data = client.getRecords()

# %%
data.head()
# Out:
#   unique_key             created_date              closed_date agency  \
# 0   59226807  2023-10-26T12:00:00.000  2023-10-26T12:00:00.000   DSNY
# 1   59220291  2023-10-26T12:00:00.000                      NaN   DSNY
# 2   59228123  2023-10-26T12:00:00.000  2023-10-26T12:00:00.000   DSNY
# 3   59226822  2023-10-26T12:00:00.000                      NaN   DSNY
# 4   59222887  2023-10-26T12:00:00.000                      NaN   DSNY
#
#                 agency_name     complaint_type         descriptor  \
# 0  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 1  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 3  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 4  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
#
#   location_type incident_zip      incident_address  ...  \
# 0        Street        10473     1696 BANYER PLACE  ...
# ...

# %%
# get records on selected columns
select = ["unique_key",	"created_date",	"closed_date", "complaint_type", "status"]
data = client.getRecords(select=select)

# %%
data.head()
# Out:
#   unique_key             created_date              closed_date  \
# 0   59226807  2023-10-26T12:00:00.000  2023-10-26T12:00:00.000
# 1   59226822  2023-10-26T12:00:00.000                      NaN
# 2   59224196  2023-10-26T12:00:00.000  2023-10-26T12:00:00.000
# 3   59222887  2023-10-26T12:00:00.000                      NaN
# 4   59228123  2023-10-26T12:00:00.000  2023-10-26T12:00:00.000
#
#       complaint_type  status
# 0  Derelict Vehicles  Closed
# 1  Derelict Vehicles    Open
# 2  Derelict Vehicles  Closed
# 3  Derelict Vehicles    Open
# 4  Derelict Vehicles  Closed

# %%
# get records with a query string
query = """SELECT unique_key, created_date, closed_date, complaint_type, status WHERE status = 'Open' ORDER BY created_date"""
data = client.getRecordsQuery(query=query)

# %%
data.head()
# Out:
#   unique_key             created_date        complaint_type status  \
# 0   15636218  2010-01-01T00:00:00.000  GENERAL CONSTRUCTION   Open
# 1   15635737  2010-01-01T00:00:00.000  GENERAL CONSTRUCTION   Open
# 2   15635769  2010-01-01T00:00:00.000               HEATING   Open
# 3   15636284  2010-01-01T16:39:20.000              Graffiti   Open
# 4   15639059  2010-01-02T00:00:00.000              NONCONST   Open
#
#                closed_date
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  2010-01-01T16:39:20.000
# 4                      NaN
